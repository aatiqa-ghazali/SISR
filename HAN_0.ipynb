# %% [markdown]
# <a href="https://colab.research.google.com/github/aatiqa-ghazali/SISR/blob/main/HAN_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mounting_drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **ECCV 2020 paper "Single Image Super-Resolution via a Holistic Attention Network**

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:23
# 🔁 Restarting kernel...

# %%
# !pip uninstall torch -y
# !pip uninstall torch -y
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torch as it is not installed.

# %%
# !pip install torch===0.4.1.post2 torchvision===0.2.1
# Out:
# ...
#      |████████████████████████████████| 519.5 MB 22 kB/s
# ...
#      |████████████████████████████████| 54 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 77.4 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 48.1 MB/s
# ...

# %%
# !pip install numpy
# !pip install imageio
# !pip install matplotlib
# !pip install tqdm
# !apt-get install python-opencv
# !python -m pip install -U scikit-image
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 7.1 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 247 kB 72.0 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 95.0 MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   python-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 535 kB of archives.
# After this operation, 2,944 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [535 kB]
# Fetched 535 kB in 1s (517 kB/s)
# Selecting previously unselected package python-opencv.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../python-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# ...

# %%
# !conda install -c conda-forge scikit-image
# Out:
# Error processing line 1 of /usr/local/lib/python3.7/site-packages/matplotlib-3.4.3-py3.7-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/usr/local/lib/python3.7/site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 580, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.0               |       h9c3ff4c_0         841 KB  conda-forge
#     brotli-1.0.9               |       h7f98852_5          17 KB  conda-forge
#     brotli-bin-1.0.9           |       h7f98852_5          19 KB  conda-forge
# ...

# %%
# !torch.cuda.is_available()
# Out:
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
 # !sh '/content/drive/MyDrive/SISR/HAN/src/demo.sh'
# Out:
# Making model...
# Load the model from /content/drive/MyDrive/SISR/HAN/experiment/model/RCAN_BIX2.pt
# Preparing loss function:
# 1.000 * MSE
# [Epoch 0]	Learning rate: 1.00e-4
#
# Evaluation:
# 100%|███████████████████████████████████████████| 20/20 [00:13<00:00,  1.44it/s]
# [Set20 x4]	PSNR: 15.511 (Best: 15.511 @epoch 0)
# Forward: 14.05s
#
# Saving...
# Total: 14.94s
#
# [Epoch 1]	Learning rate: 1.00e-4
#
# Evaluation:
# 100%|███████████████████████████████████████████| 20/20 [00:14<00:00,  1.43it/s]
# [Set20 x4]	PSNR: 15.511 (Best: 15.511 @epoch 0)
# Forward: 14.17s
#
# Saving...
# Total: 14.92s
#
# [Epoch 2]	Learning rate: 1.00e-4
#
# Evaluation:
# 100%|███████████████████████████████████████████| 20/20 [00:13<00:00,  1.43it/s]
# [Set20 x4]	PSNR: 15.511 (Best: 15.511 @epoch 0)
# Forward: 14.10s
#
# Saving...
# Total: 14.84s
#
# [Epoch 3]	Learning rate: 1.00e-4
#
# Evaluation:
# 100%|███████████████████████████████████████████| 20/20 [00:13<00:00,  1.43it/s]
# ...
