# %% [markdown]
# <a href="https://colab.research.google.com/github/aatiqa-ghazali/SISR/blob/main/RCAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mounting_drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Image Super-Resolution Using Very Deep Residual Channel Attention Networks**
#
# **Requirements**:
#
# Python >=3.6
#
# torch===0.4.1.post2
#
# torchvision===0.2.1
#
# numpy
#
# skimage
#
# imageio
#
# matplotlib
#
# tqdm
#
# cv2 >= 3.xx (Only if you want to use video input/output)
#
# **Commands for converting png files into binary files**
#
# In options.py set --ext to sep_reset for the first time
# and then sep for skipping after conversion
# (If more RAM is avilable we can use --ext==bin to pack all images in to 1 binary files)
#
# **Errors faced during training**
# >using binrary files that were converted with another torch version in this version gave an error "ValueError: Cannot load file containing pickled data when allow_pickle=False"
#
# >Now if i set allow-pickle=true another error popped up related to OS
#
#
# >after searching i found that i was loading binary files converted in another version of torch in this version so i converted them again in this case.

# %%
# !pip uninstall torch -y
# Out:
# Found existing installation: torch 1.9.0+cu111
# Uninstalling torch-1.9.0+cu111:
#   Successfully uninstalled torch-1.9.0+cu111

# %%
# !pip uninstall torch -y
# Out:
# WARNING: Skipping torch as it is not installed.

# %%
# !pip install torch===0.4.1.post2 torchvision===0.2.1
# Out:
# ...
#      |████████████████████████████████| 519.5 MB 22 kB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 62.1 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 50.1 MB/s
# ...

# %%
# !pip install numpy
# !pip install imageio
# !pip install matplotlib
# !pip install tqdm
# !apt-get install python-opencv
# !python -m pip install -U scikit-image
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.0 MB/s
# ...
#      |████████████████████████████████| 247 kB 51.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.9 MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   python-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 535 kB of archives.
# After this operation, 2,944 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [535 kB]
# Fetched 535 kB in 1s (759 kB/s)
# Selecting previously unselected package python-opencv.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../python-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# ...

# %%
# !python '/content/drive/MyDrive/SISR/RCAN/RCAN/RCAN_TrainCode/code/main.py' --model RCAN --save RCAN_BIX2_G10R20P48 --scale 2 --n_resgroups 10 --n_resblocks 20 --n_feats 64  --reset --chop --save_results --print_model --patch_size 96
# Out:
# Making model...
# RCAN(
#   (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (head): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (body): Sequential(
#     (0): ResidualGroup(
#       (body): Sequential(
#         (0): RCAB(
#           (body): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace)
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (3): CALayer(
#               (avg_pool): AdaptiveAvgPool2d(output_size=1)
#               (conv_du): Sequential(
#                 (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace)
#                 (2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (3): Sigmoid()
#               )
#             )
#           )
# ...
