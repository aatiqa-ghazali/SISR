# %% [markdown]
# <a href="https://colab.research.google.com/github/aatiqa-ghazali/SISR/blob/main/RCAN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mounting_drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Enhanced Deep Residual Networks for Single Image Super-Resolution" from CVPRW 2017, 2nd NTIRE.**
#
#
# https://github.com/sanghyun-son/EDSR-PyTorch

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install pytorch torchvision -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     blas-2.106                 |              mkl          12 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_0         144 KB  conda-forge
#     conda-4.10.3               |   py37h89c1867_2         3.1 MB  conda-forge
#     cudatoolkit-11.1.1         |       h6406543_8        1.20 GB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
# ...

# %%
# !pip install numpy
# !pip install imageio
# !pip install matplotlib
# !pip install tqdm

# %%
# !apt-get install python-opencv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   python-opencv
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 535 kB of archives.
# After this operation, 2,944 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [535 kB]
# Fetched 535 kB in 1s (782 kB/s)
# Selecting previously unselected package python-opencv.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../python-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking python-opencv (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up python-opencv (3.2.0+dfsg-4ubuntu0.1) ...

# %%
# !cd '/content/drive/MyDrive/SISR/EDSR-PyTorch'

# %%
# !python -m pip install -U scikit-image
# Out:
# ...
#      |████████████████████████████████| 29.2 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 174 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 42.5 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 51.9 MB/s
# ...

# %%
# !pip uninstall torch -y
# Out:
# WARNING: Skipping torch as it is not installed.

# %%
# !pip uninstall torch -y
# Out:
# Found existing installation: torch 0.4.1
# Uninstalling torch-0.4.1:
#   Successfully uninstalled torch-0.4.1

# %%
# !pip install torch===0.4.1.post2 torchvision===0.2.1
# Out:
# ...
#      |████████████████████████████████| 519.5 MB 20 kB/s
# ...

# %%
# !python '/content/drive/MyDrive/SISR/RCAN/RCAN/RCAN_TrainCode/code/main.py' --model RCAN --save RCAN_BIX2_G10R20P48 --scale 2 --n_resgroups 10 --n_resblocks 20 --n_feats 64  --reset --chop --save_results --print_model --patch_size 96
# Out:
# /usr/local/lib/python3.7/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# Preparing seperated binary files
# Preparing seperated binary files
# Making model...
# RCAN(
#   (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (head): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (body): Sequential(
#     (0): ResidualGroup(
#       (body): Sequential(
#         (0): RCAB(
#           (body): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace)
# ...

# %%
 # !sh '/content/drive/MyDrive/SISR/EDSR-PyTorch/src/demo.sh'
# Out:
# /usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Making model...
# Preparing loss function:
# 1.000 * L1
# /usr/local/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:417: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# [Epoch 1]	Learning rate: 1.00e-4
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SISR/EDSR-PyTorch/src/main.py", line 33, in <module>
#     main()
#   File "/content/drive/MyDrive/SISR/EDSR-PyTorch/src/main.py", line 27, in main
# ...
